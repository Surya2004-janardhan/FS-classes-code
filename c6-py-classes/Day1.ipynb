# %% [markdown]
# #python
# - Python is a high-level, interpreted, dynamically typed, object-oriented programming language.

# %%
a = 10
type(a)

# java == int a = 10;
# Out:
# int

# %%
var = input("Enter a number: ")
var = int(var)  # Convert string input to integer
print("You entered:", var)
print(type(var))
# Out:
# You entered: 10
# <class 'int'>

# %%
var1 = input("Enter a float number: ")
print(type(var1))
var1 = float(var1)  # Convert string input to float
print("You entered:", var1)
print(type(var1))
# Out:
# <class 'str'>
# You entered: 12.12
# <class 'float'>

# %%
int_var = int("123")
str_var = str(int_var)

# %%
tr = str(input())
print(tr)
# Out:
# your

# %%
a = 1
a = 12

print(a)
# Out:
# 12

# %%
# + - * 
# / // % **

a = 5
b = 2
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b) #expensive division
print(a % b)
print(a ** b) #expensive
# Out:
# 7
# 3
# 10
# 2.5
# 2
# 1
# 25

# %%
== 
>=
<=
!=
# if else elif while i++ i<

# %%
# logical operators
if not "" , 0, None, False ,[] , () , {}:
    print("srikant is eligible for job")
else:

or
not
# assignment operators
i++ i-- 
i +=  1
-= 
/= 
*= 
%=

# %%
print(bool(""))  # False
print(bool(0))   # False
print(bool(None))  # False
print(bool(False))  # False
print(bool([]))   # False
print(bool(()))   # False
print(bool({}))   # False
print(bool(""))  # True
print(bool(-43))   # True
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# True

# %%
and = & 2 & 3 - 
or = |
not = ~ 2
xor ^ 
 1 1 0 
 / / /
1 1 0 0 
\ \ \ 
0 1 1 0


1 0 1 - 5
^
-------
0 1 1 - 3
-----

<<
>>

# %%
a = 6 
b  = 5
print(a ^ b)

# ram = ram assignment oper = 
# ram = 5
# ram += 3  # ram = ram + 3
ram == ram # comparison operator
# Out:
# 3

# %%
in  # membership operator
is  # identity operator
not in
is not

# %%
a = [2,5,6]
print(2  not in a )
print("s" not in "srikant")
# Out:
# False
# False

# %%
# is , ==
# 
a = 653545453453
b = 653545453453
print(a == b) # True compares values
print(a  is not b) # compares memory locations
# Out:
# True
# True
